# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
stars_df = pd.read_csv("stardata.txt")
stars_df
# Out:
#       Cluster Number  Running Number in Cluster  Star Number (in UBV Source)  \
# 0                  1                          1                          454
# 1                  1                          1                          454
# 2                  1                          1                          454
# 3                  1                          2                            0
# 4                  1                          2                            0
# ...              ...                        ...                          ...
# 9874              68                         31                           18
# 9875              68                         32                           41
# 9876              68                         33                            8
# 9877              68                         34                           15
# 9878              68                         35                           20
#
# ...

# %%
x = stars_df.iloc[:,3]
y = stars_df.iloc[:,7]
color = stars_df.iloc[:,6]

plt.figure(figsize=(11,9))
plt.title("Hertzsprung-Russel Diagram")
plt.xlabel("Blue-Violet Color Index")
plt.ylabel("Log of Luminosity (solLum)")
# plt.gca().invert_yaxis()

plt.scatter(x, y, c=color, cmap="inferno", s=0.5)
plt.colorbar(label="Log of Effective Temp (K)")

# %%
gaia_df = pd.read_csv("top2000_temp_lum-result.csv")
gaia_df
# Out:
#       teff_gspphot  lum_flame
# 0              NaN        NaN
# 1              NaN        NaN
# 2              NaN        NaN
# 3              NaN        NaN
# 4              NaN        NaN
# ...            ...        ...
# 1995           NaN        NaN
# 1996           NaN        NaN
# 1997           NaN        NaN
# 1998           NaN        NaN
# 1999           NaN        NaN
#
# [2000 rows x 2 columns]

# %%
x = gaia_df.iloc[:,0]
y = np.log10(gaia_df.iloc[:,1])
# color = stars_df.iloc[:,6]

plt.figure(figsize=(7,7))
plt.title("Hertzsprung-Russel Diagram")
# plt.xlabel("Blue-Violet Color Index")
# plt.ylabel("Log of Luminosity (solLum)")
# plt.gca().invert_yaxis()

plt.scatter(x, y, s=1)
# plt.colorbar(label="Log of Effective Temp (K)")
